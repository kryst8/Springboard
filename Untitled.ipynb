# %% [markdown]
#    # Data Analysis Interview Challenge : Ultimate

# %% [markdown]
# # Part 1 : Exploratory data analysis

# %% [markdown]
# #### Load our packages

# %%
# Importing Packages
import json
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Reading json file
logins = pd.read_json('/Users/devonbrewster/Downloads/ultimate_challenge/logins.json')

# %%
logins
# Out:
#                login_time
# 0     1970-01-01 20:13:18
# 1     1970-01-01 20:16:10
# 2     1970-01-01 20:16:37
# 3     1970-01-01 20:16:36
# 4     1970-01-01 20:26:21
# ...                   ...
# 93137 1970-04-13 18:50:19
# 93138 1970-04-13 18:43:56
# 93139 1970-04-13 18:54:02
# 93140 1970-04-13 18:57:38
# 93141 1970-04-13 18:54:23
#
# [93142 rows x 1 columns]

# %%
logins.info
# Out:
# <bound method DataFrame.info of                login_time
# 0     1970-01-01 20:13:18
# 1     1970-01-01 20:16:10
# 2     1970-01-01 20:16:37
# 3     1970-01-01 20:16:36
# 4     1970-01-01 20:26:21
# ...                   ...
# 93137 1970-04-13 18:50:19
# 93138 1970-04-13 18:43:56
# 93139 1970-04-13 18:54:02
# 93140 1970-04-13 18:57:38
# 93141 1970-04-13 18:54:23
#
# [93142 rows x 1 columns]>

# %% [markdown]
# #### Add a column called "count" to represent the number of logins during each time

# %%
logins['count'] = 1

# %%
logins
# Out:
#                login_time  count
# 0     1970-01-01 20:13:18      1
# 1     1970-01-01 20:16:10      1
# 2     1970-01-01 20:16:37      1
# 3     1970-01-01 20:16:36      1
# 4     1970-01-01 20:26:21      1
# ...                   ...    ...
# 93137 1970-04-13 18:50:19      1
# 93138 1970-04-13 18:43:56      1
# 93139 1970-04-13 18:54:02      1
# 93140 1970-04-13 18:57:38      1
# 93141 1970-04-13 18:54:23      1
#
# [93142 rows x 2 columns]

# %%
logins.set_index('login_time', inplace=True)

# %% [markdown]
# #### Aggregate these login counts based on 15­ minute time intervals

# %%
login_intervale = logins.resample('15Min').sum()

# %%
login_intervale.head()
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1

# %% [markdown]
# #### Please report/illustrate important features of the demand,such as daily cycles.

# %%
login_intervale.plot(kind= "line", figsize=(20, 8))

# %% [markdown]
# ## Part II: Experiment and metrics design

# %% [markdown]
# #### 1. What would you choose as the key measure of success of this experiment inencouraging driver partners to serve both cities, and why would you choose this metric

# %% [markdown]
# #### The metirc I would use to measure the success of this experiment would be to see how much money is being reimburset for the toll bridge. If we notice an increase in the money the managers are using to reimburse their drivers then that mean drivers are trveling between the cities and making use of the opportunity. Secondly, another metric we could also use is looking at the amout of driving requests (demand) in the morning and at night. If there is an increase in requests in morning in Gotham and and increase of requests at night in Metropolis, then this decision made by the managers is effective.

# %% [markdown]
# #### 2. Describe a practical experiment you would design to compare the effectiveness of the proposed change in relation to the key measure of success. Please provide details on:a.how you will implement the experimentb.what statistical test(s) you will conduct to verify the significance of theobservationc.how you would interpret the results and provide recommendations to the cityoperations team along with any caveats.

# %% [markdown]
# #### A pratical experiment that I would use to see how effective it it is using hypothesis testing. I would have a null hypothesis that states there is not increase in the drivers each city. Then I will caluculate how much money is being reimbused on the tolls. My hope is that as the reimbursment increases, the demand for care request will increase. The statistical test that I would use is one sample mean test. This will allow me to test whether the sample median differs from the hypothesized mean (no change in demand).
